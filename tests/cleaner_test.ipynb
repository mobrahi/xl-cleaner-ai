# %%
# In another terminal
top -l 1 | grep -E "PhysMem|Ollama"

# %% [markdown]
# # Close other apps (Chrome, Slack, etc.)
# # Process files with <10,000 rows first
# # Use CSV instead of Excel for faster loading

# %%
# First, test your model
python cleaner.py benchmark

# %%
# Then clean a small file
python cleaner.py clean test.csv

# %% [markdown]
# # Monitor memory while it runs
# # In another terminal: memory pressure
